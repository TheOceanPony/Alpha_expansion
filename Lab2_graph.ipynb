# %% [markdown]
# # Lab 2 Alpha-expansion

# %%
import copy
import numpy as np

from numpy.random import shuffle
import matplotlib.pyplot as plt
from tqdm import tqdm

import funcs as f
import utils as utl

# %%
from time import time
start = time()

# %% [markdown]
# ---

# %%
C = np.array([1, 128, 255])
repeats = 5
img = utl.import_img("input_2.jpg", bw=True, newshape=(100,200))
# Out:
# Input size:  (200, 100)
# dtype: uint8 | max: 252 | min: 9

# %% [markdown]
# # Main

# %%
labeling = f.initial_labeling(img, C)

for iteration in tqdm(range(repeats)):
    a_shuffle = np.copy(C)
    shuffle(a_shuffle)
    
    for i in range(C.size):

        # 1) alpha_i
        a_i = a_shuffle[i]

        # 2) initial labeling
        k_init = labeling

        # 3) init new graph
        g = f.init_g(img, k_init, a_i, scale=100)

        # 4) solve for new binary task
        res = f.Ford_Falkerson(img, g)
        labeling = f.translate_to_labeling(res, k_init, a_i)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [01:50<00:00, 22.10s/it]

# %%
print(f"Time: {time() - start}")
plt.subplots(figsize=(10, 10))
plt.imshow(np.reshape(labeling, (200,100)), cmap='gray')
# Out:
# Time: 111.52472114562988

# %% [markdown]
# ---
